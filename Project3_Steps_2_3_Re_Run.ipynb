# %% [markdown]
# <a href="https://colab.research.google.com/github/Mzrcin47/Project3/blob/main/Project3_Steps_2_3_Re_Run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Project3-850
# Out:
# /content/gdrive/MyDrive/Project3-850

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# %cd /content/gdrive/MyDrive/Project3-850/Project3Data/data
# Out:
# /content/gdrive/MyDrive/Project3-850/Project3Data/data

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=125 imgsz=900 plots=True batch=2
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

model.predict(['/content/gdrive/MyDrive/Project3-850/Project3Data/data/evaluation/ardmega.jpg', '/content/gdrive/MyDrive/Project3-850/Project3Data/data/evaluation/arduno.jpg', '/content/gdrive/MyDrive/Project3-850/Project3Data/data/evaluation/rasppi.jpg'], save=True, imgsz=320, conf=0.1)
# Out:
# WARNING ⚠️ NMS time limit 0.650s exceeded
# 0: 320x320 1 book, 1: 320x320 (no detections), 2: 320x320 (no detections), 122.5ms
# Speed: 1.5ms preprocess, 40.8ms inference, 236.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict8
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
